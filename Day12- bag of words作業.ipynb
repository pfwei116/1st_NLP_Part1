# %% [markdown]
# ## 搭建一個bag of words模型

# %% [markdown]
# ---

# %%
# %load_ext autotime
# Out:
# time: 0 ns

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# time: 15 ms

# %%
#設定要保留的字
import re
pattern = r"[^A-Za-z ]"

for i in range(corpus.shape[0]):
    corpus[i] = re.sub(pattern, '', corpus[i])
# Out:
# time: 0 ns

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    for word in sentence.split(' '):
        whole_words.append(word)
# Out:
# time: 0 ns

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = list(set(whole_words))
whole_words = [ i for i in whole_words if len(i) > 0 ]
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2324個單字
# time: 0 ns

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
whole_words[:10]
# Out:
# ['Nicest',
#  'salad',
#  'mess',
#  'toasted',
#  'sewer',
#  'waiter',
#  'military',
#  'i',
#  'somewhat',
#  'human']
# time: 0 ns

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n += 1
# Out:
# time: 0 ns

# %%
word_index
# Out:
# {'Nicest': 0,
#  'salad': 1,
#  'mess': 2,
#  'toasted': 3,
#  'sewer': 4,
#  'waiter': 5,
#  'military': 6,
#  'i': 7,
#  'somewhat': 8,
#  'human': 9,
#  'BACK': 10,
#  'compliments': 11,
#  'else': 12,
#  'ten': 13,
#  'quick': 14,
#  'Attack': 15,
#  'seasoned': 16,
#  'topvery': 17,
#  'neither': 18,
#  'serving': 19,
#  'fondue': 20,
#  'dirty': 21,
#  'suggest': 22,
#  'Very': 23,
#  'tepid': 24,
#  'Valley': 25,
#  'inch': 26,
#  'disgusted': 27,
#  'because': 28,
#  'over': 29,
#  'subpar': 30,
#  'covered': 31,
#  'upgrading': 32,
#  'humiliated': 33,
#  'dripping': 34,
#  'thats': 35,
#  'occasions': 36,
#  'nasty': 37,
#  'luck': 38,
#  'enjoyable': 39,
#  'Kind': 40,
#  'caught': 41,
#  'guacamole': 42,
#  'chipolte': 43,
#  'rinse': 44,
#  'Veggitarian': 45,
#  'Insults': 46,
#  'decorated': 47,
#  'NOT': 48,
#  'paper': 49,
#  'tolerance': 50,
#  'IN': 51,
#  'tartar': 52,
#  'rated': 53,
#  'simply': 54,
#  'particular': 55,
#  'rude': 56,
#  'That': 57,
# ...

# %%
index_word
# Out:
# {0: 'Nicest',
#  1: 'salad',
#  2: 'mess',
#  3: 'toasted',
#  4: 'sewer',
#  5: 'waiter',
#  6: 'military',
#  7: 'i',
#  8: 'somewhat',
#  9: 'human',
#  10: 'BACK',
#  11: 'compliments',
#  12: 'else',
#  13: 'ten',
#  14: 'quick',
#  15: 'Attack',
#  16: 'seasoned',
#  17: 'topvery',
#  18: 'neither',
#  19: 'serving',
#  20: 'fondue',
#  21: 'dirty',
#  22: 'suggest',
#  23: 'Very',
#  24: 'tepid',
#  25: 'Valley',
#  26: 'inch',
#  27: 'disgusted',
#  28: 'because',
#  29: 'over',
#  30: 'subpar',
#  31: 'covered',
#  32: 'upgrading',
#  33: 'humiliated',
#  34: 'dripping',
#  35: 'thats',
#  36: 'occasions',
#  37: 'nasty',
#  38: 'luck',
#  39: 'enjoyable',
#  40: 'Kind',
#  41: 'caught',
#  42: 'guacamole',
#  43: 'chipolte',
#  44: 'rinse',
#  45: 'Veggitarian',
#  46: 'Insults',
#  47: 'decorated',
#  48: 'NOT',
#  49: 'paper',
#  50: 'tolerance',
#  51: 'IN',
#  52: 'tartar',
#  53: 'rated',
#  54: 'simply',
#  55: 'particular',
#  56: 'rude',
#  57: 'That',
# ...

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic):
    sentence = sentence
    vector = []
    
    import re
    pattern = r"[^A-Za-z ]"
    sentence = re.sub(pattern, '', sentence)
    
    for word in sentence.split(' '):
        vector.append(word_index_dic.get(word,-1))
            
    return vector
# Out:
# time: 0 ns

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index)
# Out:
# [1653, 1185, 1386, 549]
# time: 0 ns
